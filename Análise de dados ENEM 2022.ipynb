# %% [markdown]
# # Análise dos Microdados do ENEM

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
microdadosEnem = pd.read_csv("C:/Users/55319/Desktop/DadosEnem22/DADOS\MICRODADOS_ENEM_2022.csv", sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdadosEnem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210057943671    2022               14       M                2
# 1        210057516120    2022               14       M                2
# 2        210057280536    2022                5       F                1
# 3        210055724397    2022                6       M                1
# 4        210055097896    2022                4       M                0
# ...               ...     ...              ...     ...              ...
# 3476100  210056389903    2022                3       M                1
# 3476101  210057205644    2022               14       F                2
# 3476102  210056699189    2022                2       M                1
# 3476103  210056983033    2022                3       M                1
# 3476104  210056307777    2022                2       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
microdadosEnem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadasEnem = ['TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO','NO_MUNICIPIO_ESC','NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TP_LINGUA',
       'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO']

# %%
microdadosEnemSelecionados = microdadosEnem.filter(items=colunasSelecionadasEnem)

# %%
microdadosEnemSelecionados.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  \
# 0               14       M                2            2                 1
# 1               14       M                2            1                 1
# 2                5       F                1            2                 1
# 3                6       M                1            3                 1
# 4                4       M                0            3                 1
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO NO_MUNICIPIO_ESC  \
# 0                1                2          1        NaN              NaN
# 1                1               16          1        NaN              NaN
# 2                1                2          1        NaN              NaN
# 3                1                2          1        NaN              NaN
# 4                1                1          1        NaN              NaN
#
# ...

# %%
coluna_no_municipio_esc = microdadosEnemSelecionados['NO_MUNICIPIO_ESC']

# %%
coluna_no_municipio_esc
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 3476100        NaN
# 3476101    Caruaru
# 3476102      Lages
# 3476103     Guaíra
# 3476104    Goiânia
# Name: NO_MUNICIPIO_ESC, Length: 3476105, dtype: object

# %%
coluna_no_municipio_esc.value_counts().sort_index()
# Out:
# NO_MUNICIPIO_ESC
# Abadia de Goiás         60
# Abadia dos Dourados     18
# Abadiânia              153
# Abaetetuba             830
# Abaeté                  67
#                       ...
# Áurea                    4
# Ângulo                  16
# Érico Cardoso           17
# Óbidos                 137
# Óleo                    11
# Name: count, Length: 5265, dtype: int64

# %%
coluna_faixa_etaria = microdadosEnemSelecionados['TP_FAIXA_ETARIA']

# %%
coluna_faixa_etaria.value_counts().sort_index()
# Out:
# TP_FAIXA_ETARIA
# 1     303605
# 2     711278
# 3     805862
# 4     408115
# 5     247679
# 6     165982
# 7     123260
# 8      94849
# 9      73338
# 10     61564
# 11    189700
# 12    103634
# 13     74162
# 14     49735
# 15     30066
# 16     17688
# 17      9688
# 18      3817
# 19      1505
# 20       578
# Name: count, dtype: int64

# %%
coluna_faixa_etaria.hist(bins=30)
# Out:
# <Axes: >

# %%
colunasSelecionadas = ['TP_SEXO', 'NU_NOTA_REDACAO']

# %%
microdadosEnemSexoRedacao = microdadosEnem.filter(items=colunasSelecionadas)

# %%
microdadosEnemSexoRedacao.head()
# Out:
#   TP_SEXO  NU_NOTA_REDACAO
# 0       M              NaN
# 1       M              NaN
# 2       F            760.0
# 3       M            320.0
# 4       M              NaN

# %%
microdadosEnemSexoRedacao = microdadosEnemSexoRedacao.dropna()

# %%
microdadosEnemSexoRedacao.head()
# Out:
#    TP_SEXO  NU_NOTA_REDACAO
# 2        F            760.0
# 3        M            320.0
# 7        F            440.0
# 9        F            360.0
# 11       F            940.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').count()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                1530098
# M                 963344

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').max()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 1000.0
# M                 1000.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                    0.0
# M                    0.0

# %%
microdadosEnemSexoRedacao[microdadosEnemSexoRedacao.NU_NOTA_REDACAO > 0].groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                   40.0
# M                   40.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').mean()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F             628.922919
# M             601.892533

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').median()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                  640.0
# M                  600.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').hist()
# Out:
# TP_SEXO
# F    [[Axes(0.125,0.11;0.775x0.77)]]
# M    [[Axes(0.125,0.11;0.775x0.77)]]
# dtype: object

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F             1530098.0  628.922919  213.217841  0.0  540.0  640.0  780.0
# M              963344.0  601.892533  209.538737  0.0  520.0  600.0  740.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0

# %%
colunasSelecionadas = ['NU_INSCRICAO', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002']

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadas)

# %%
microdadosEnemSelecionado = microdadosEnemSelecionado.dropna()

# %%
microdadosEnemSelecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 2   210057280536       565.3            760.0    E    F
# 3   210055724397       416.0            320.0    C    A
# 7   210055778089       404.9            440.0    E    E
# 9   210055461467       435.3            360.0    E    E
# 11  210054972570       456.8            940.0    E    E

# %%
q001e002Dicionario = {
'A' : 'Nunca estudou.',
'B' : 'Não completou a 4ª série/5º ano do Ensino Fundamental.',
'C' : 'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.',
'D' : 'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.',
'E' : 'Completou o Ensino Médio, mas não completou a Faculdade.',
'F' : 'Completou a Faculdade, mas não completou a Pós-graduação.',
'G' : 'Completou a Pós-graduação.',
'H' : 'Não sei.'}

# %%
microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]

# %%
microdadosEnemSelecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 2   210057280536       565.3            760.0    E    F
# 3   210055724397       416.0            320.0    C    A
# 7   210055778089       404.9            440.0    E    E
# 9   210055461467       435.3            360.0    E    E
# 11  210054972570       456.8            940.0    E    E
#
#                                               NO_Q001
# 2   Completou o Ensino Médio, mas não completou a ...
# 3   Completou a 4ª série/5º ano, mas não completou...
# 7   Completou o Ensino Médio, mas não completou a ...
# 9   Completou o Ensino Médio, mas não completou a ...
# 11  Completou o Ensino Médio, mas não completou a ...

# %%
microdadosEnemSelecionado['NO_Q002'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q002]

# %%
microdadosEnemSelecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 2   210057280536       565.3            760.0    E    F
# 3   210055724397       416.0            320.0    C    A
# 7   210055778089       404.9            440.0    E    E
# 9   210055461467       435.3            360.0    E    E
# 11  210054972570       456.8            940.0    E    E
#
#                                               NO_Q001  \
# 2   Completou o Ensino Médio, mas não completou a ...
# 3   Completou a 4ª série/5º ano, mas não completou...
# 7   Completou o Ensino Médio, mas não completou a ...
# 9   Completou o Ensino Médio, mas não completou a ...
# 11  Completou o Ensino Médio, mas não completou a ...
#
#                                               NO_Q002
# 2   Completou a Faculdade, mas não completou a Pós...
# 3                                      Nunca estudou.
# 7   Completou o Ensino Médio, mas não completou a ...
# 9   Completou o Ensino Médio, mas não completou a ...
# ...

# %% [markdown]
# 1 - Dsitribuição dos candidatos do ENEM 2022 por escolaridade do Pai

# %%
microdadosEnemSelecionado.filter(items=['NU_INSCRICAO','NO_Q001']).groupby('NO_Q001').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q001
# Completou o Ensino Médio, mas não completou a F...        720913
# Não completou a 4ª série/5º ano do Ensino Funda...        350284
# Completou a 4ª série/5º ano, mas não completou ...        291859
# Completou a 8ª série/9º ano do Ensino Fundament...        259673
# Completou a Faculdade, mas não completou a Pós-...        250540
# Não sei.                                                  202637
# Completou a Pós-graduação.                                193050
# Nunca estudou.                                             75867

# %% [markdown]
# 2 - Dsitribuição dos candidatos do ENEM 2022 por escolaridade da Mãe

# %%
microdadosEnemSelecionado.filter(items=['NU_INSCRICAO','NO_Q002']).groupby('NO_Q002').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q002
# Completou o Ensino Médio, mas não completou a F...        851162
# Completou a Faculdade, mas não completou a Pós-...        329384
# Completou a Pós-graduação.                                322603
# Completou a 8ª série/9º ano do Ensino Fundament...        262334
# Não completou a 4ª série/5º ano do Ensino Funda...        238683
# Completou a 4ª série/5º ano, mas não completou ...        232165
# Não sei.                                                   62486
# Nunca estudou.                                             46006

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_MT','NO_Q001']).groupby('NO_Q001').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q001
# Completou a Pós-graduação.                          622.681863
# Completou a Faculdade, mas não completou a Pós-...  606.265275
# Completou o Ensino Médio, mas não completou a F...  550.539180
# Completou a 8ª série/9º ano do Ensino Fundament...  528.257192
# Completou a 4ª série/5º ano, mas não completou ...  518.945360
# Não sei.                                            509.209243
# Não completou a 4ª série/5º ano do Ensino Funda...  500.422448
# Nunca estudou.                                      477.496748

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_MT','NO_Q002']).groupby('NO_Q002').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q002
# Completou a Pós-graduação.                          602.375859
# Completou a Faculdade, mas não completou a Pós-...  591.089336
# Completou o Ensino Médio, mas não completou a F...  540.254915
# Completou a 8ª série/9º ano do Ensino Fundament...  515.969635
# Completou a 4ª série/5º ano, mas não completou ...  507.631458
# Não sei.                                            497.162744
# Não completou a 4ª série/5º ano do Ensino Funda...  492.413723
# Nunca estudou.                                      470.632798

# %%
Q002 = microdadosEnemSelecionado.filter(items=['NU_NOTA_MT','NO_Q002']).groupby('NO_Q002').mean().sort_values(by='NU_NOTA_MT', ascending=False)

# %%
Q002.plot()
# Out:
# <Axes: xlabel='NO_Q002'>

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_MT','NO_Q002']).groupby('NO_Q002').describe()
# Out:
#                                                    NU_NOTA_MT              \
#                                                         count        mean
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...   232165.0  507.631458
# Completou a 8ª série/9º ano do Ensino Fundament...   262334.0  515.969635
# Completou a Faculdade, mas não completou a Pós-...   329384.0  591.089336
# Completou a Pós-graduação.                           322603.0  602.375859
# Completou o Ensino Médio, mas não completou a F...   851162.0  540.254915
# Nunca estudou.                                        46006.0  470.632798
# Não completou a 4ª série/5º ano do Ensino Funda...   238683.0  492.413723
# Não sei.                                              62486.0  497.162744
#
#                                                                             \
#                                                            std  min    25%
# NO_Q002
# ...

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002']).groupby('NO_Q002').describe()
# Out:
#                                                    NU_NOTA_REDACAO  \
#                                                              count
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...        232165.0
# Completou a 8ª série/9º ano do Ensino Fundament...        262334.0
# Completou a Faculdade, mas não completou a Pós-...        329384.0
# Completou a Pós-graduação.                                322603.0
# Completou o Ensino Médio, mas não completou a F...        851162.0
# Nunca estudou.                                             46006.0
# Não completou a 4ª série/5º ano do Ensino Funda...        238683.0
# Não sei.                                                   62486.0
#
#                                                                             \
#                                                           mean         std
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...  576.363104  204.275752
# ...

# %%
microdadosEnemSelecionado['SG_UF_RESIDENCIA'] = microdadosEnem.SG_UF_ESC

# %%
microdadosEnemSelecionado.dropna().head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 40  210056717205       430.4            560.0    C    D
# 55  210056012033       905.5            900.0    D    F
# 57  210056292241       551.9            740.0    C    D
# 59  210054772114       433.6            520.0    E    E
# 67  210055580862       438.0            540.0    D    E
#
#                                               NO_Q001  \
# 40  Completou a 4ª série/5º ano, mas não completou...
# 55  Completou a 8ª série/9º ano do Ensino Fundamen...
# 57  Completou a 4ª série/5º ano, mas não completou...
# 59  Completou o Ensino Médio, mas não completou a ...
# 67  Completou a 8ª série/9º ano do Ensino Fundamen...
#
#                                               NO_Q002 SG_UF_RESIDENCIA
# 40  Completou a 8ª série/9º ano do Ensino Fundamen...               CE
# 55  Completou a Faculdade, mas não completou a Pós...               SP
# 57  Completou a 8ª série/9º ano do Ensino Fundamen...               GO
# ...

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002'])\
                        .where(microdadosEnemSelecionado.SG_UF_RESIDENCIA == 'RJ')\
                        .groupby('NO_Q002')\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               764.708647
# Completou a Faculdade, mas não completou a Pós-...       738.085059
# Completou o Ensino Médio, mas não completou a F...       648.956219
# Completou a 8ª série/9º ano do Ensino Fundament...       603.404479
# Completou a 4ª série/5º ano, mas não completou ...       589.098186
# Não completou a 4ª série/5º ano do Ensino Funda...       562.476658
# Não sei.                                                 546.114152
# Nunca estudou.                                           515.193798

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002'])\
                        .where(microdadosEnemSelecionado.SG_UF_RESIDENCIA == 'SP')\
                        .groupby('NO_Q002')\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               711.793902
# Completou a Faculdade, mas não completou a Pós-...       696.217478
# Completou o Ensino Médio, mas não completou a F...       632.472141
# Completou a 8ª série/9º ano do Ensino Fundament...       599.542259
# Completou a 4ª série/5º ano, mas não completou ...       590.590622
# Não completou a 4ª série/5º ano do Ensino Funda...       570.911356
# Não sei.                                                 553.774834
# Nunca estudou.                                           524.710579

# %%
microdadosEnemSelecionado.filter(items=['SG_UF_RESIDENCIA','NU_NOTA_REDACAO','NO_Q002'])\
                        .groupby(['SG_UF_RESIDENCIA','NO_Q002'])\
                        .mean()
# Out:
#                                                                      NU_NOTA_REDACAO
# SG_UF_RESIDENCIA NO_Q002
# AC               Completou a 4ª série/5º ano, mas não completou ...       548.363636
#                  Completou a 8ª série/9º ano do Ensino Fundament...       552.696246
#                  Completou a Faculdade, mas não completou a Pós-...       663.745020
#                  Completou a Pós-graduação.                               715.263158
#                  Completou o Ensino Médio, mas não completou a F...       600.564263
# ...                                                                              ...
# TO               Completou a Pós-graduação.                               684.520397
#                  Completou o Ensino Médio, mas não completou a F...       587.686567
#                  Nunca estudou.                                           502.500000
#                  Não completou a 4ª série/5º ano do Ensino Funda...       478.796992
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16,8))
plt.suptitle('Nota Redação x Escolaridade x Estado')

microdadosEnemSelecionado.filter(items=['SG_UF_RESIDENCIA','Q002','NU_NOTA_REDACAO'])\
                        .where(microdadosEnemSelecionado.Q002 != 'H')\
                        .groupby(['Q002', 'SG_UF_RESIDENCIA'])\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
                        .unstack().plot(ax=ax, )
# Out:
# <Axes: xlabel='Q002'>

# %%
#fig, ax = plt.subplots(figsize=(16,8))
#plt.suptitle('Nota Redação x Escolaridade x Estado')

ax = microdadosEnemSelecionado.filter(items=['SG_UF_RESIDENCIA','Q002','NU_NOTA_REDACAO'])\
                        .groupby(['Q002', 'SG_UF_RESIDENCIA'])\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
                        .unstack().plot(figsize=(16,8), grid=True)

ax.set_title('Nota Redação x Escolaridade x Estado', fontsize=20)


handles, labels = ax.get_legend_handles_labels()

import re
edited_labels = [re.search(',\s(.+?)\)', label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor=(1.08, 1), loc=0, borderaxespad=0.)

textdictQ002 = ""
for key,value in q001e002Dicionario.items():
    textdictQ002 = textdictQ002 + "{k} : {v}\n".format(k=key,v=value)

ax.text(0.02,0.68, textdictQ002, transform=ax.transAxes, fontsize=12,
       bbox={'boxstyle':'round', 'facecolor':'darkturquoise', 'alpha':0.3})
# Out:
# Text(0.02, 0.68, 'A : Nunca estudou.\nB : Não completou a 4ª série/5º ano do Ensino Fundamental.\nC : Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.\nD : Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.\nE : Completou o Ensino Médio, mas não completou a Faculdade.\nF : Completou a Faculdade, mas não completou a Pós-graduação.\nG : Completou a Pós-graduação.\nH : Não sei.\n')

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC','CO_UF_ESC','SG_UF_ESC',
                                                        'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
                                                        'NU_NOTA_MT', 'NU_NOTA_REDACAO'])

# %%
microdadosEnemSelecionado
# Out:
#          CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0                     NaN              NaN        NaN       NaN         NaN
# 1                     NaN              NaN        NaN       NaN         NaN
# 2                     NaN              NaN        NaN       NaN       421.1
# 3                     NaN              NaN        NaN       NaN       490.7
# 4                     NaN              NaN        NaN       NaN         NaN
# ...                   ...              ...        ...       ...         ...
# 3476100               NaN              NaN        NaN       NaN         NaN
# 3476101         2604106.0          Caruaru       26.0        PE         NaN
# 3476102         4209300.0            Lages       42.0        SC       527.9
# 3476103         3517406.0           Guaíra       35.0        SP         NaN
# 3476104         5208707.0          Goiânia       52.0        GO         NaN
#
# ...

# %%
mediaEnemPorMunicipio = microdadosEnemSelecionado.groupby(['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
                                                           'CO_UF_ESC','SG_UF_ESC'], as_index=False).mean()

# %%
mediaEnemPorMunicipio
# Out:
#       CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  \
# 0            1100015.0  Alta Floresta D'Oeste       11.0        RO
# 1            1100023.0              Ariquemes       11.0        RO
# 2            1100031.0                 Cabixi       11.0        RO
# 3            1100049.0                 Cacoal       11.0        RO
# 4            1100056.0             Cerejeiras       11.0        RO
# ...                ...                    ...        ...       ...
# 5532         5222005.0             Vianópolis       52.0        GO
# 5533         5222054.0         Vicentinópolis       52.0        GO
# 5534         5222203.0               Vila Boa       52.0        GO
# 5535         5222302.0          Vila Propício       52.0        GO
# 5536         5300108.0               Brasília       53.0        DF
#
#       NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0     482.898551  521.657333  499.216000  534.992754       656.533333
# ...

# %%
mediaEnemPorMunicipio.to_csv("mediaEnemPorMunicipio.csv")

# %% [markdown]
# # Nota no ENEM x IDHM

# %%
mediaEnemPorMunicipio = pd.read_csv('mediaEnemPorMunicipio.csv', sep=",", index_col=0)

# %%
mediaEnemPorMunicipio.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  482.898551
# 1         1100023.0              Ariquemes       11.0        RO  487.737168
# 2         1100031.0                 Cabixi       11.0        RO  464.870588
# 3         1100049.0                 Cacoal       11.0        RO  488.037712
# 4         1100056.0             Cerejeiras       11.0        RO  487.975000
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0  521.657333  499.216000  534.992754       656.533333
# 1  514.815818  504.606702  535.383186       613.351206
# 2  437.478947  429.742105  489.952941       436.842105
# 3  513.414600  506.028800  534.805297       602.280000
# 4  518.408696  490.573913  535.207500       609.565217

# %%
atlasHumano = pd.read_csv("C:/Users/55319/Desktop/Projetos/atlas2013.csv", sep=",")

# %%
atlasHumano
# Out:
#         ANO                UF  Codmun6  Codmun7              Município  \
# 0      1991          RONDÔNIA   110001  1100015  ALTA FLORESTA D'OESTE
# 1      1991          RONDÔNIA   110002  1100023              ARIQUEMES
# 2      1991          RONDÔNIA   110003  1100031                 CABIXI
# 3      1991          RONDÔNIA   110004  1100049                 CACOAL
# 4      1991          RONDÔNIA   110005  1100056             CEREJEIRAS
# ...     ...               ...      ...      ...                    ...
# 16690  2010             GOIÁS   522200  5222005             VIANÓPOLIS
# 16691  2010             GOIÁS   522205  5222054         VICENTINÓPOLIS
# 16692  2010             GOIÁS   522220  5222203               VILA BOA
# 16693  2010             GOIÁS   522230  5222302          VILA PROPÍCIO
# 16694  2010  DISTRITO FEDERAL   530010  5300108               BRASÍLIA
#
#             LONG        LAT          Alt  ESPVIDA  FECTOT  ...   PIA1517  \
# ...

# %%
atlasHumano.columns.values
# Out:
# array(['ANO', 'UF', 'Codmun6', 'Codmun7', 'Município', 'LONG', 'LAT',
#        'Alt', 'ESPVIDA', 'FECTOT', 'MORT1', 'MORT5', 'RAZDEP', 'SOBRE40',
#        'SOBRE60', 'T_ENV', 'E_ANOSESTUDO', 'T_ANALF11A14', 'T_ANALF15A17',
#        'T_ANALF15M', 'T_ANALF18A24', 'T_ANALF18M', 'T_ANALF25A29',
#        'T_ANALF25M', 'T_ATRASO_0_BASICO', 'T_ATRASO_0_FUND',
#        'T_ATRASO_0_MED', 'T_ATRASO_1_BASICO', 'T_ATRASO_1_FUND',
#        'T_ATRASO_1_MED', 'T_ATRASO_2_BASICO', 'T_ATRASO_2_FUND',
#        'T_ATRASO_2_MED', 'T_FBBAS', 'T_FBFUND', 'T_FBMED', 'T_FBPRE',
#        'T_FBSUPER', 'T_FLBAS', 'T_FLFUND', 'T_FLMED', 'T_FLPRE',
#        'T_FLSUPER', 'T_FREQ0A3', 'T_FREQ11A14', 'T_FREQ15A17',
#        'T_FREQ18A24', 'T_FREQ25A29', 'T_FREQ4A5', 'T_FREQ4A6',
#        'T_FREQ5A6', 'T_FREQ6', 'T_FREQ6A14', 'T_FREQ6A17',
#        'T_FREQFUND1517', 'T_FREQFUND1824', 'T_FREQFUND45',
#        'T_FREQMED1824', 'T_FREQMED614', 'T_FREQSUPER1517', 'T_FUND11A13',
# ...

# %%
colunasSelecionadasAtlas = ['ANO', 'UF', 'Codmun6', 'Codmun7', 'Município', 'IDHM', 'IDHM_E', 'IDHM_L', 'IDHM_R']

# %%
atlasHumano = atlasHumano.filter(items=colunasSelecionadasAtlas).where(atlasHumano.ANO == 2010)

# %%
atlasHumano = atlasHumano.dropna()

# %%
atlasHumano.head()
# Out:
#           ANO        UF   Codmun6    Codmun7              Município   IDHM  \
# 11130  2010.0  RONDÔNIA  110001.0  1100015.0  ALTA FLORESTA D'OESTE  0.641
# 11131  2010.0  RONDÔNIA  110002.0  1100023.0              ARIQUEMES  0.702
# 11132  2010.0  RONDÔNIA  110003.0  1100031.0                 CABIXI  0.650
# 11133  2010.0  RONDÔNIA  110004.0  1100049.0                 CACOAL  0.718
# 11134  2010.0  RONDÔNIA  110005.0  1100056.0             CEREJEIRAS  0.692
#
#        IDHM_E  IDHM_L  IDHM_R
# 11130   0.526   0.763   0.657
# 11131   0.600   0.806   0.716
# 11132   0.559   0.757   0.650
# 11133   0.620   0.821   0.727
# 11134   0.602   0.799   0.688

# %%
mediaEnemIDHM = pd.merge(mediaEnemPorMunicipio, atlasHumano, how='left', left_on=['CO_MUNICIPIO_ESC'], right_on=['Codmun7'])

# %%
mediaEnemIDHM.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  482.898551
# 1         1100023.0              Ariquemes       11.0        RO  487.737168
# 2         1100031.0                 Cabixi       11.0        RO  464.870588
# 3         1100049.0                 Cacoal       11.0        RO  488.037712
# 4         1100056.0             Cerejeiras       11.0        RO  487.975000
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO     ANO        UF  \
# 0  521.657333  499.216000  534.992754       656.533333  2010.0  RONDÔNIA
# 1  514.815818  504.606702  535.383186       613.351206  2010.0  RONDÔNIA
# 2  437.478947  429.742105  489.952941       436.842105  2010.0  RONDÔNIA
# 3  513.414600  506.028800  534.805297       602.280000  2010.0  RONDÔNIA
# 4  518.408696  490.573913  535.207500       609.565217  2010.0  RONDÔNIA
#
# ...

# %%
mediaEnemIDHM['IDHM'] = mediaEnemIDHM['IDHM'].apply(lambda x: float(str(x).replace(",",".")))
mediaEnemIDHM['IDHM_E'] = mediaEnemIDHM['IDHM_E'].apply(lambda x: float(str(x).replace(",",".")))
mediaEnemIDHM['IDHM_L'] = mediaEnemIDHM['IDHM_L'].apply(lambda x: float(str(x).replace(",",".")))
mediaEnemIDHM['IDHM_R'] = mediaEnemIDHM['IDHM_R'].apply(lambda x: float(str(x).replace(",",".")))

# %%
mediaEnemIDHM.dtypes
# Out:
# CO_MUNICIPIO_ESC    float64
# NO_MUNICIPIO_ESC     object
# CO_UF_ESC           float64
# SG_UF_ESC            object
# NU_NOTA_CN          float64
# NU_NOTA_CH          float64
# NU_NOTA_LC          float64
# NU_NOTA_MT          float64
# NU_NOTA_REDACAO     float64
# ANO                 float64
# UF                   object
# Codmun6             float64
# Codmun7             float64
# Município            object
# IDHM                float64
# IDHM_E              float64
# IDHM_L              float64
# IDHM_R              float64
# dtype: object

# %%
mediaEnemIDHM.plot.scatter('NU_NOTA_MT', 'IDHM', figsize=(10,10))
# Out:
# <Axes: xlabel='NU_NOTA_MT', ylabel='IDHM'>

# %%
mediaEnemIDHM.plot.scatter('NU_NOTA_REDACAO', 'IDHM', figsize=(10,5))
# Out:
# <Axes: xlabel='NU_NOTA_REDACAO', ylabel='IDHM'>

# %% [markdown]
# ## Transformando o gráfico em 4 quadrantes

# %%
mean_REDACAO = mediaEnemIDHM.NU_NOTA_REDACAO.mean()
mean_IDHM = mediaEnemIDHM.IDHM.mean()

# %%
mean_REDACAO
# Out:
# 557.4935986900267

# %%
mean_IDHM
# Out:
# 0.6590278330019881

# %%
idhmMunicipio = mediaEnemIDHM.IDHM
notaMunicipio = mediaEnemIDHM.NU_NOTA_REDACAO

quadrante1 = (idhmMunicipio < mean_IDHM) & (notaMunicipio < mean_REDACAO)
quadrante2 = (idhmMunicipio > mean_IDHM) & (notaMunicipio < mean_REDACAO)
quadrante3 = (idhmMunicipio > mean_IDHM) & (notaMunicipio > mean_REDACAO)
quadrante4 = (idhmMunicipio < mean_IDHM) & (notaMunicipio > mean_REDACAO)

mediaEnemIDHM1 = mediaEnemIDHM[quadrante1]
mediaEnemIDHM1.plot.scatter('NU_NOTA_REDACAO', 'IDHM')

mediaEnemIDHM2 = mediaEnemIDHM[quadrante2]
mediaEnemIDHM2.plot.scatter('NU_NOTA_REDACAO', 'IDHM')

mediaEnemIDHM3 = mediaEnemIDHM[quadrante3]
mediaEnemIDHM3.plot.scatter('NU_NOTA_REDACAO', 'IDHM')

mediaEnemIDHM4 = mediaEnemIDHM[quadrante4]
mediaEnemIDHM4.plot.scatter('NU_NOTA_REDACAO', 'IDHM')
# Out:
# <Axes: xlabel='NU_NOTA_REDACAO', ylabel='IDHM'>

# %%
idhmMunicipio = mediaEnemIDHM.IDHM
notaMunicipio = mediaEnemIDHM.NU_NOTA_REDACAO

quadrante1 = (idhmMunicipio < mean_IDHM) & (notaMunicipio < mean_REDACAO)
quadrante2 = (idhmMunicipio > mean_IDHM) & (notaMunicipio < mean_REDACAO)
quadrante3 = (idhmMunicipio > mean_IDHM) & (notaMunicipio > mean_REDACAO)
quadrante4 = (idhmMunicipio < mean_IDHM) & (notaMunicipio > mean_REDACAO)

fig, ax = plt.subplots(2,2, figsize=(20,10), sharex='col', sharey='row') #a contagem é de cima pra baixo, da esquerda pra direita
plt.subplots_adjust(wspace=0, hspace=0)

minRedacao = mediaEnemIDHM.NU_NOTA_REDACAO.min()
minIDHM = mediaEnemIDHM.IDHM.min()
maxRedacao = mediaEnemIDHM.NU_NOTA_REDACAO.max()
maxIDHM = mediaEnemIDHM.IDHM.max()

mediaEnemIDHM1 = mediaEnemIDHM[quadrante1]
mediaEnemIDHM1.plot.scatter('NU_NOTA_REDACAO', 'IDHM', color='purple', s=6, ax=ax[1,0], xlim = (minRedacao, mean_REDACAO), ylim = (minIDHM, mean_IDHM))
print("Quadrante 1: {}%, baixo IDHM, baixa nota".format(100*len(mediaEnemIDHM1.IDHM)/len(idhmMunicipio)))

mediaEnemIDHM2 = mediaEnemIDHM[quadrante2]
mediaEnemIDHM2.plot.scatter('NU_NOTA_REDACAO', 'IDHM', s=6, ax=ax[0,0], xlim = (minRedacao, mean_REDACAO), ylim = (mean_IDHM, maxIDHM))
print("Quadrante 2: {}%, alto IDHM, baixa nota".format(100*len(mediaEnemIDHM2.IDHM)/len(idhmMunicipio)))

mediaEnemIDHM3 = mediaEnemIDHM[quadrante3]
mediaEnemIDHM3.plot.scatter('NU_NOTA_REDACAO', 'IDHM', color='green', s=6, ax=ax[0,1], xlim = (mean_REDACAO, maxRedacao), ylim = (mean_IDHM, maxIDHM))
print("Quadrante 3: {}%, alto IDHM, alta nota".format(100*len(mediaEnemIDHM3.IDHM)/len(idhmMunicipio)))

mediaEnemIDHM4 = mediaEnemIDHM[quadrante4]
mediaEnemIDHM4.plot.scatter('NU_NOTA_REDACAO', 'IDHM', color='orange', s=6, ax=ax[1,1], xlim = (mean_REDACAO, maxRedacao), ylim = (minIDHM, mean_IDHM))
print("Quadrante 4: {}%, baixo IDHM, alta nota".format(100*len(mediaEnemIDHM4.IDHM)/len(idhmMunicipio)))
# Out:
# Quadrante 1: 28.625609535849737%, baixo IDHM, baixa nota
# Quadrante 2: 17.15730540003612%, alto IDHM, baixa nota
# Quadrante 3: 34.856420444283906%, alto IDHM, alta nota
# Quadrante 4: 18.69243272530251%, baixo IDHM, alta nota

# %%
atlasHumano = pd.read_csv("atlas2013.csv", sep=",")

# %%
latLong = ['Codmun7', 'LONG', 'LAT','ANO']

# %%
dtLatLong = atlasHumano.filter(items=latLong).where(atlasHumano.ANO==2010)

# %%
dtLatLong=dtLatLong.dropna()
dtLatLong.head()
# Out:
#          Codmun7       LONG        LAT     ANO
# 11130  1100015.0 -61.999824 -11.935540  2010.0
# 11131  1100023.0 -63.033269  -9.908463  2010.0
# 11132  1100031.0 -60.544314 -13.499763  2010.0
# 11133  1100049.0 -61.442944 -11.433865  2010.0
# 11134  1100056.0 -60.818426 -13.195033  2010.0

# %%
enem_idhm_municiopios = pd.merge(mediaEnemIDHM, dtLatLong, 
                                 how='left', left_on=['CO_MUNICIPIO_ESC'], 
                                 right_on=['Codmun7'])

# %%
enem_idhm_municiopios.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  482.898551
# 1         1100023.0              Ariquemes       11.0        RO  487.737168
# 2         1100031.0                 Cabixi       11.0        RO  464.870588
# 3         1100049.0                 Cacoal       11.0        RO  488.037712
# 4         1100056.0             Cerejeiras       11.0        RO  487.975000
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO   ANO_x  ...  \
# 0  521.657333  499.216000  534.992754       656.533333  2010.0  ...
# 1  514.815818  504.606702  535.383186       613.351206  2010.0  ...
# 2  437.478947  429.742105  489.952941       436.842105  2010.0  ...
# 3  513.414600  506.028800  534.805297       602.280000  2010.0  ...
# 4  518.408696  490.573913  535.207500       609.565217  2010.0  ...
#
#    Codmun7_x              Município   IDHM IDHM_E  IDHM_L  IDHM_R  Codmun7_y  \
# ...

# %%
enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['NU_NOTA_REDACAO'],
                                   cmap='RdYlGn',
                                   figsize=(10,8), title='NU_NOTA_REDACAO')
# Out:
# <Axes: title={'center': 'NU_NOTA_REDACAO'}, xlabel='LONG', ylabel='LAT'>

# %%
fig, ax = plt.subplots(2,2, figsize=(20,16))

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['NU_NOTA_CN'],
                                   cmap='RdYlGn',
                                   title='NU_NOTA_CN', ax=ax[0,0])

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['NU_NOTA_CH'],
                                   cmap='RdYlGn',
                                   title='NU_NOTA_CH', ax=ax[0,1])

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['NU_NOTA_LC'],
                                   cmap='RdYlGn',
                                   title='NU_NOTA_LC', ax=ax[1,0])

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['NU_NOTA_MT'],
                                   cmap='RdYlGn',
                                   title='NU_NOTA_MT', ax=ax[1,1])
# Out:
# <Axes: title={'center': 'NU_NOTA_MT'}, xlabel='LONG', ylabel='LAT'>

# %%
fig, ax = plt.subplots(2,2, figsize=(20,15))

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['IDHM'],
                                   cmap='coolwarm',
                                   title='IDHM', ax=ax[0,0])

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['IDHM_E'],
                                   cmap='coolwarm',
                                   title='IDHM_E', ax=ax[0,1])

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['IDHM_R'],
                                   cmap='coolwarm',
                                   title='IDHM_R', ax=ax[1,0])

enem_idhm_municiopios.plot.scatter(y='LAT',x='LONG', 
                                   c=enem_idhm_municiopios['IDHM_L'],
                                   cmap='coolwarm',
                                   title='IDHM_L', ax=ax[1,1])
# Out:
# <Axes: title={'center': 'IDHM_L'}, xlabel='LONG', ylabel='LAT'>
